# %%
#import dependencies
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import sqlite3
import matplotlib.pyplot as plt

# %%
movie_file = "Resources1/movies_metadata1.csv"
movie_df = pd.read_csv(movie_file)
movie_df.head()
# Out:
# /Users/theriotn95/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
# Create a filtered dataframe from specific columns
movies_cols = [ "imdb_id","title", "budget", "release_date", "popularity" ]
movies_df= movie_df[movies_cols].copy()


movies_df['budget'] = pd.to_numeric(movies_df['budget'], errors='coerce')
movies_df['budget'] = movies_df['budget'].replace(0, np.nan)
movies_df[movies_df['budget'].isnull()].shape

# Clean the data by dropping duplicates and setting the index
movies_df.drop_duplicates("title", inplace=True)
movies_df['imdb_id'] = movies_df['imdb_id'].str[3:]

movies_df=movies_df.rename(columns={'imdb_id':'imdbId'})

cleaned_df = movies_df.dropna()
cleaned_df['imdbId'] = cleaned_df['imdbId'].astype('int64')
cleaned_df
# Out:
# /Users/theriotn95/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        imdbId                             title      budget release_date  \
# 0      114709                         Toy Story  30000000.0   1995-10-30
# 1      113497                           Jumanji  65000000.0   1995-12-15
# 3      114885                 Waiting to Exhale  16000000.0   1995-12-22
# 5      113277                              Heat  60000000.0   1995-12-15
# 6      114319                           Sabrina  58000000.0   1995-12-15
# ...       ...                               ...         ...          ...
# 45398  742932  Thick Lashes of Lauri Mäntyvaara   1254040.0   2017-07-28
# 45399  805180                       All at Once    750000.0   2014-06-05
# 45402  761706                   Corporate Event   2000000.0   2014-09-18
# 45412  718881                       Pro Lyuboff   2000000.0   2010-09-30
# 45422  110037                           Antidur   5000000.0   2007-09-06
#
#       popularity
# 0        21.9469
# 1        17.0155
# 3        3.85949
# 5        17.9249
# 6        6.67728
# ...          ...
# 45398   0.347806
# 45399   0.201582
# 45402    0.52437
# 45412   0.121844
# 45422   0.039793
#
# [8255 rows x 5 columns]

# %%
print(cleaned_df.dtypes)
# Out:
# imdbId            int64
# title            object
# budget          float64
# release_date     object
# popularity       object
# dtype: object

# %%
disneydata =pd.read_csv('Resources1/disney_movies1.csv', parse_dates=['release_date'])
disneydata=disneydata.rename(columns={'movie_title':'title'})

disneydata
# Out:
#                                title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# 1       84300000                2188229052
# 2       83320000                2187090808
# 3       65000000                1078510579
# 4       85000000                 920608730
# ..           ...                       ...
# 574     12545979                  12545979
# 575      8874389                   8874389
# 576    232532923                 232532923
# 577    246082029                 246082029
# 578    529483936                 529483936
#
# [579 rows x 6 columns]

# %%
rating_file = "Resources1/ratings_small1.csv"
rating_df = pd.read_csv(rating_file)
rating_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
link_file = "Resources1/links_small1.csv"
link_df = pd.read_csv(link_file)
link_df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
# Create a filtered dataframe from specific columns
links_cols = ["movieId","imdbId"]
links_df= link_df[links_cols].copy()

links_df.set_index("movieId", inplace=True)

links_df.head()
# Out:
#          imdbId
# movieId
# 1        114709
# 2        113497
# 3        113228
# 4        114885
# 5        113041

# %%
# Create a filtered dataframe from specific columns
ratings_cols = ["movieId","rating"]
ratings_df= rating_df[ratings_cols].copy()

ratings_df.set_index("movieId", inplace=True)

ratings_df.head()
# Out:
#          rating
# movieId
# 31          2.5
# 1029        3.0
# 1061        3.0
# 1129        2.0
# 1172        4.0

# %%
# Create a filtered dataframe from specific columns
links_cols = ["movieId","imdbId"]
links_df= link_df[links_cols].copy()

links_df.head()
# Out:
#    movieId  imdbId
# 0        1  114709
# 1        2  113497
# 2        3  113228
# 3        4  114885
# 4        5  113041

# %%
# merge on movieid to prepare for final data frame
imdbratings_df = pd.merge(ratings_df, links_df, on='movieId', how='inner')


imdbratings_df
# Out:
#         movieId  rating  imdbId
# 0            31     2.5  112792
# 1            31     3.0  112792
# 2            31     4.0  112792
# 3            31     4.0  112792
# 4            31     3.0  112792
# ...         ...     ...     ...
# 99999     64997     2.5  449040
# 100000    72380     3.5  362478
# 100001      129     3.0  114131
# 100002     4736     1.0  234829
# 100003     6425     1.0  120142
#
# [100004 rows x 3 columns]

# %%
# calculate the average rating for each movie
avg_ratings = imdbratings_df.groupby('imdbId', as_index=False)['rating'].mean()

avg_ratings
# Out:
#        imdbId    rating
# 0         417  4.333333
# 1        4972  3.000000
# 2        6333  3.500000
# 3        8133  4.250000
# 4        9018  4.250000
# ...       ...       ...
# 9061  5278868  4.500000
# 9062  5480340  5.000000
# 9063  5595168  3.000000
# 9064  5613056  4.000000
# 9065  5794766  0.500000
#
# [9066 rows x 2 columns]

# %%
final_movies_df = pd.merge(cleaned_df, avg_ratings, on='imdbId', how='inner')


final_movies_df
# Out:
#       imdbId                           title       budget release_date  \
# 0     114709                       Toy Story   30000000.0   1995-10-30
# 1     113497                         Jumanji   65000000.0   1995-12-15
# 2     114885               Waiting to Exhale   16000000.0   1995-12-22
# 3     113277                            Heat   60000000.0   1995-12-15
# 4     114319                         Sabrina   58000000.0   1995-12-15
# ...      ...                             ...          ...          ...
# 3548  113448                       All-Stars     608000.0   2014-10-15
# 3549  918940            The Legend of Tarzan  180000000.0   2016-06-29
# 3550  255313  The Last Brickmaker in America    8000000.0   2001-09-23
# 3551   91538                      Max & Leon   12156348.0   2016-11-01
# 3552  185906                Band of Brothers  125000000.0   2001-09-09
#
#      popularity    rating
# 0       21.9469  3.872470
# 1       17.0155  3.401869
# 2       3.85949  2.384615
# 3       17.9249  3.884615
# 4       6.67728  3.283019
# ...         ...       ...
# 3548   0.610104  4.000000
# 3549   45.38298  2.500000
# 3550   0.038998  5.000000
# 3551   5.662109  3.772727
# 3552   7.903731  4.386364
#
# [3553 rows x 6 columns]

# %%
#merge to create the final disney dataframe to uplaod into postgres
disney_df = pd.merge(final_movies_df, disneydata, on='title', how='inner')
disney_df
# Out:
#      imdbId            title       budget release_date_x popularity    rating  \
# 0    114709        Toy Story   30000000.0     1995-10-30    21.9469  3.872470
# 1    113987            Nixon   44000000.0     1995-12-22      5.092  3.451613
# 2    112819  Dead Presidents   10000000.0     1995-10-06    9.87957  2.333333
# 3    114148       Pocahontas   55000000.0     1995-06-14    13.2801  2.926230
# 4    118158     White Squall   38000000.0     1996-02-02     9.5686  3.764706
# ..      ...              ...          ...            ...        ...       ...
# 241  398286          Tangled  260000000.0     2010-11-24    14.6848  3.666667
# 242  433035       Real Steel  110000000.0     2011-09-28    19.2656  3.000000
# 243  401729      John Carter  260000000.0     2012-03-07    14.6704  2.937500
# 244  443272          Lincoln   65000000.0     2012-11-09    10.6803  3.428571
# 245  478970          Ant-Man  130000000.0     2015-07-14    26.8824  3.794118
#
#     release_date_y      genre mpaa_rating  total_gross  \
# 0       1995-11-22  Adventure           G    191796233
# 1       1995-12-20      Drama           R     13668249
# 2       1995-10-04      Drama           R     24120194
# 3       1995-06-10  Adventure           G    141579773
# 4       1996-02-02  Adventure       PG-13     10229300
# ..             ...        ...         ...          ...
# 241     2010-11-24  Adventure          PG    200821936
# 242     2011-10-07     Action       PG-13     85463309
# 243     2012-03-09  Adventure       PG-13     73058679
# 244     2012-11-09      Drama       PG-13    182207973
# 245     2015-07-17     Action       PG-13    180202163
#
#      inflation_adjusted_gross
# 0                   370409631
# 1                    26302005
# 2                    46741467
# 3                   274370957
# 4                    19509726
# ..                        ...
# 241                 214388548
# 242                  90848019
# 243                  77372445
# 244                 192122330
# 245                 180202163
#
# [246 rows x 11 columns]

# %%
disney_df=disney_df.rename(columns={'release_date_x':'release_date'})
disney_df.drop_duplicates("title", inplace=True)
del disney_df['release_date_y']
disney_df
# Out:
#      imdbId            title       budget release_date popularity    rating  \
# 0    114709        Toy Story   30000000.0   1995-10-30    21.9469  3.872470
# 1    113987            Nixon   44000000.0   1995-12-22      5.092  3.451613
# 2    112819  Dead Presidents   10000000.0   1995-10-06    9.87957  2.333333
# 3    114148       Pocahontas   55000000.0   1995-06-14    13.2801  2.926230
# 4    118158     White Squall   38000000.0   1996-02-02     9.5686  3.764706
# ..      ...              ...          ...          ...        ...       ...
# 241  398286          Tangled  260000000.0   2010-11-24    14.6848  3.666667
# 242  433035       Real Steel  110000000.0   2011-09-28    19.2656  3.000000
# 243  401729      John Carter  260000000.0   2012-03-07    14.6704  2.937500
# 244  443272          Lincoln   65000000.0   2012-11-09    10.6803  3.428571
# 245  478970          Ant-Man  130000000.0   2015-07-14    26.8824  3.794118
#
#          genre mpaa_rating  total_gross  inflation_adjusted_gross
# 0    Adventure           G    191796233                 370409631
# 1        Drama           R     13668249                  26302005
# 2        Drama           R     24120194                  46741467
# 3    Adventure           G    141579773                 274370957
# 4    Adventure       PG-13     10229300                  19509726
# ..         ...         ...          ...                       ...
# 241  Adventure          PG    200821936                 214388548
# 242     Action       PG-13     85463309                  90848019
# 243  Adventure       PG-13     73058679                  77372445
# 244      Drama       PG-13    182207973                 192122330
# 245     Action       PG-13    180202163                 180202163
#
# [244 rows x 10 columns]

# %%
del disney_df['imdbId']
print(disney_df.dtypes)
# Out:
# title                        object
# budget                      float64
# release_date                 object
# popularity                   object
# rating                      float64
# genre                        object
# mpaa_rating                  object
# total_gross                   int64
# inflation_adjusted_gross      int64
# dtype: object

# %%
disney_movies = disney_df.set_index('title')
disney_movies
# Out:
#                       budget release_date popularity    rating      genre  \
# title
# Toy Story         30000000.0   1995-10-30    21.9469  3.872470  Adventure
# Nixon             44000000.0   1995-12-22      5.092  3.451613      Drama
# Dead Presidents   10000000.0   1995-10-06    9.87957  2.333333      Drama
# Pocahontas        55000000.0   1995-06-14    13.2801  2.926230  Adventure
# White Squall      38000000.0   1996-02-02     9.5686  3.764706  Adventure
# ...                      ...          ...        ...       ...        ...
# Tangled          260000000.0   2010-11-24    14.6848  3.666667  Adventure
# Real Steel       110000000.0   2011-09-28    19.2656  3.000000     Action
# John Carter      260000000.0   2012-03-07    14.6704  2.937500  Adventure
# Lincoln           65000000.0   2012-11-09    10.6803  3.428571      Drama
# Ant-Man          130000000.0   2015-07-14    26.8824  3.794118     Action
#
#                 mpaa_rating  total_gross  inflation_adjusted_gross
# title
# Toy Story                 G    191796233                 370409631
# Nixon                     R     13668249                  26302005
# Dead Presidents           R     24120194                  46741467
# Pocahontas                G    141579773                 274370957
# White Squall          PG-13     10229300                  19509726
# ...                     ...          ...                       ...
# Tangled                  PG    200821936                 214388548
# Real Steel            PG-13     85463309                  90848019
# John Carter           PG-13     73058679                  77372445
# Lincoln               PG-13    182207973                 192122330
# Ant-Man               PG-13    180202163                 180202163
#
# [244 rows x 8 columns]

# %%
#reaorganize in order to create various matplotlib charts
budget_cols = [ "title","budget","inflation_adjusted_gross" ]
budget_df= disney_df[budget_cols].copy()
budget_df['profit'] = budget_df['inflation_adjusted_gross'] - budget_df['budget']
budget_df.head(10)
# Out:
#                  title      budget  inflation_adjusted_gross       profit
# 0            Toy Story  30000000.0                 370409631  340409631.0
# 1                Nixon  44000000.0                  26302005  -17697995.0
# 2      Dead Presidents  10000000.0                  46741467   36741467.0
# 3           Pocahontas  55000000.0                 274370957  219370957.0
# 4         White Squall  38000000.0                  19509726  -18490274.0
# 5     Before and After  35000000.0                  16482589  -18517411.0
# 6  Up Close & Personal  60000000.0                  97356578   37356578.0
# 7         Crimson Tide  53000000.0                 177102077  124102077.0
# 8          Judge Dredd  90000000.0                  67222776  -22777224.0
# 9   The Scarlet Letter  50000000.0                  20075033  -29924967.0

# %%
profit_cols = [ "title","profit"]
profit_df= budget_df[profit_cols].copy()
profit_df
# Out:
#                title       profit
# 0          Toy Story  340409631.0
# 1              Nixon  -17697995.0
# 2    Dead Presidents   36741467.0
# 3         Pocahontas  219370957.0
# 4       White Squall  -18490274.0
# ..               ...          ...
# 241          Tangled  -45611452.0
# 242       Real Steel  -19151981.0
# 243      John Carter -182627555.0
# 244          Lincoln  127122330.0
# 245          Ant-Man   50202163.0
#
# [244 rows x 2 columns]

# %%
sort_by_profit = profit_df.sort_values('profit',ascending=False)
sort_by_profit.set_index("title", inplace=True)

sort_by_profit.head(20)
# Out:
#                                        profit
# title
# Snow White and the Seven Dwarfs  5.227465e+09
# Pinocchio                        2.185629e+09
# Fantasia                         2.184811e+09
# 101 Dalmatians                   1.308871e+09
# Cinderella                       9.177087e+08
# The Lion King                    7.166409e+08
# The Avengers                     6.000812e+08
# 20,000 Leagues Under the Sea     5.232800e+08
# The Sixth Sense                  4.454247e+08
# Finding Nemo                     4.241486e+08
# Aladdin                          4.139692e+08
# Alice in Wonderland              3.540635e+08
# Pretty Woman                     3.423898e+08
# Toy Story                        3.404096e+08
# Beauty and the Beast             3.380177e+08
# Toy Story 2                      3.144504e+08
# Monsters, Inc.                   3.010732e+08
# The Santa Clause                 2.763697e+08
# The Waterboy                     2.656918e+08
# The Incredibles                  2.624887e+08

# %%
profit = [52.27, 21.86, 21.85, 13.09, 9.18, 7.17, 6.0, 5.23, 4.45, 4.24]
index = ['Snow White and the Seven Dwarfs', 'Pinocchio', 'Fantasia', '101 Dalmatians', 'Cinderella', 'The Lion King', 
        'The Avengers', '20,000 Leagues Under the Sea', 'The Sixth Sense', 'Finding Nemo']
 
# Create bars and choose color
plt.bar(index, profit, color = (0.5,0.1,0.5,0.6))

# Add title and axis names
plt.title('Most Profitable Movies')
plt.xlabel('Movies')
plt.ylabel('Profit (hundred million $)')
 
# Limits for the Y axis
plt.ylim(0,55)
 
# Create names
plt.xticks(index)
plt.xticks(rotation=90)
plt.figure(figsize=(10,5)) 

plt.savefig ('Images1/fig2-copy.png')

# Show chart
plt.show()

# %% [markdown]
# Snow White and the Seven Dwarfs is the most porfitable Disney movie in this dataset. With some other classic Disney movies right behind and with the amounts in hundred of millions the most succesful movies offset the losses of some of the least profitable Disney movies.

# %%
sort_by_profit = profit_df.sort_values('profit',ascending=True)
sort_by_profit.set_index("title", inplace=True)

sort_by_profit.head(20)
# Out:
#                                                profit
# title
# John Carter                              -182627555.0
# The 13th Warrior                         -105737852.0
# Treasure Planet                           -84810855.0
# The Sorcerer's Apprentice                 -82526895.0
# Around the World in 80 Days               -77414644.0
# The Chronicles of Narnia: Prince Caspian  -58722962.0
# King Arthur                               -49576294.0
# Tangled                                   -45611452.0
# The Insider                               -42205786.0
# Home on the Range                         -42089834.0
# Shadow Conspiracy                         -41042975.0
# Holy Man                                  -38305395.0
# Surrogates                                -36638584.0
# Meet the Robinsons                        -30139411.0
# The Scarlet Letter                        -29924967.0
# Big Trouble                               -29462812.0
# Bound by Honor                            -25843916.0
# Deep Rising                               -24863225.0
# Instinct                                  -23404158.0
# Judge Dredd                               -22777224.0

# %%
profit = [182.63, 105.74, 84.81, 82.53, 77.41, 58.72, 49.58, 45.61, 42.21, 42.09]
index = ['John Carter', 'The 13th Warrior', 'Treasure Planet', 'The Sorcerers Apprentice', 'Around the World in 80 Days', 
         'The Chronicles of Narnia: Prince Caspian', 'King Arthur', 'Tangled', 'The Insider', 'Home on the Range']

 
# Create bars and choose color
plt.bar(index, profit, color = (0.5,0.1,0.5,0.6))
 
# Add title and axis names
plt.title('Least Profitable Movies')
plt.xlabel('Movies')
plt.ylabel('Total Lost (millions $)')
 
# Limits for the Y axis
plt.ylim(25,190)
 
# Create names
plt.xticks(index)
plt.xticks(rotation=80)
plt.figure(figsize=(10,5))  

plt.savefig ('Images1/fig3-copy.png')

# Show chart
plt.show()

# %% [markdown]
# John Carter is the least profitable Disney movie by a long margin.

# %%
import seaborn as sns

budget_plot = sns.relplot(kind='scatter', x='budget', y='inflation_adjusted_gross', hue='title', data=budget_df.head(15))

budget_plot.savefig("Images1/fig4-copy.png")

# %% [markdown]
# This chart displays the relationship between the budget and gross revenue in hundreds of millions and we can see The Scarlet Letter has the highest budget.

# %%
import seaborn as sns
 
profit_plot = sns.relplot(kind='scatter', x='profit', y='inflation_adjusted_gross', hue='title', data=budget_df.head(15))

profit_plot.savefig("Images1/fig5-copy.png")

# %% [markdown]
# This chart displays the relationship between the profit and gross revenue in hundreds of millions and we can see Toy Story has the highest profit.

# %%
#Create database connection to postgres
connection_string = "postgres:postgres@localhost:5432/movies_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['final_disney', 'disney_table']

# %%
#upload pandas datframe into SQL table
disney_movies.to_sql(name='disney_table', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                     self.dialect.do_executemany(
# -> 1228                         cursor, statement, parameters, context
#    1229                     )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     856         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 857             cursor.executemany(statement, parameters)
#     858             return
#
# UniqueViolation: duplicate key value violates unique constraint "disney_table_pkey"
# DETAIL:  Key (title)=(Toy Story) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-28-799cfb1b2166> in <module>
#       1 #upload pandas datframe into SQL table
# ----> 2 disney_movies.to_sql(name='disney_table', con=engine, if_exists='append', index=True)
#       3
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     982             )
#     983         else:
# --> 984             return meth(self, multiparams, params)
#     985
#     986     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     291     def _execute_on_connection(self, connection, multiparams, params):
#     292         if self.supports_execution:
# --> 293             return connection._execute_clauseelement(self, multiparams, params)
#     294         else:
#     295             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1101             distilled_params,
#    1102             compiled_sql,
# -> 1103             distilled_params,
#    1104         )
#    1105         if self._has_events or self.engine._has_events:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1286         except BaseException as e:
#    1287             self._handle_dbapi_exception(
# -> 1288                 e, statement, parameters, cursor, context
#    1289             )
#    1290
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1480             elif should_wrap:
#    1481                 util.raise_(
# -> 1482                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1483                 )
#    1484             else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1226                 if not evt_handled:
#    1227                     self.dialect.do_executemany(
# -> 1228                         cursor, statement, parameters, context
#    1229                     )
#    1230             elif not parameters and context.no_parameters:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     855     def do_executemany(self, cursor, statement, parameters, context=None):
#     856         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 857             cursor.executemany(statement, parameters)
#     858             return
#     859
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "disney_table_pkey"
# DETAIL:  Key (title)=(Toy Story) already exists.
#
# [SQL: INSERT INTO disney_table (title, budget, release_date, popularity, rating, genre, mpaa_rating, total_gross, inflation_adjusted_gross) VALUES (%(title)s, %(budget)s, %(release_date)s, %(popularity)s, %(rating)s, %(genre)s, %(mpaa_rating)s, %(total_gross)s, %(inflation_adjusted_gross)s)]
# [parameters: ({'title': 'Toy Story', 'budget': 30000000.0, 'release_date': '1995-10-30', 'popularity': 21.946943, 'rating': 3.8724696356275303, 'genre': 'Adventure', 'mpaa_rating': 'G', 'total_gross': 191796233, 'inflation_adjusted_gross': 370409631}, {'title': 'Nixon', 'budget': 44000000.0, 'release_date': '1995-12-22', 'popularity': 5.092, 'rating': 3.4516129032258065, 'genre': 'Drama', 'mpaa_rating': 'R', 'total_gross': 13668249, 'inflation_adjusted_gross': 26302005}, {'title': 'Dead Presidents', 'budget': 10000000.0, 'release_date': '1995-10-06', 'popularity': 9.87957, 'rating': 2.3333333333333335, 'genre': 'Drama', 'mpaa_rating': 'R', 'total_gross': 24120194, 'inflation_adjusted_gross': 46741467}, {'title': 'Pocahontas', 'budget': 55000000.0, 'release_date': '1995-06-14', 'popularity': 13.280069000000001, 'rating': 2.9262295081967213, 'genre': 'Adventure', 'mpaa_rating': 'G', 'total_gross': 141579773, 'inflation_adjusted_gross': 274370957}, {'title': 'White Squall', 'budget': 38000000.0, 'release_date': '1996-02-02', 'popularity': 9.568603999999999, 'rating': 3.764705882352941, 'genre': 'Adventure', 'mpaa_rating': 'PG-13', 'total_gross': 10229300, 'inflation_adjusted_gross': 19509726}, {'title': 'Before and After', 'budget': 35000000.0, 'release_date': '1996-02-23', 'popularity': 2.938293, 'rating': 3.2, 'genre': 'Drama', 'mpaa_rating': 'PG-13', 'total_gross': 8642118, 'inflation_adjusted_gross': 16482589}, {'title': 'Up Close & Personal', 'budget': 60000000.0, 'release_date': '1996-03-01', 'popularity': 3.4027489999999996, 'rating': 3.4782608695652173, 'genre': 'Drama', 'mpaa_rating': 'PG-13', 'total_gross': 51045801, 'inflation_adjusted_gross': 97356578}, {'title': 'Crimson Tide', 'budget': 53000000.0, 'release_date': '1995-05-12', 'popularity': 8.657364999999999, 'rating': 3.83125, 'genre': 'Action', 'mpaa_rating': 'R', 'total_gross': 91387195, 'inflation_adjusted_gross': 177102077}  ... displaying 10 of 244 total bound parameter sets ...  {'title': 'Lincoln', 'budget': 65000000.0, 'release_date': '2012-11-09', 'popularity': 10.680330999999999, 'rating': 3.4285714285714284, 'genre': 'Drama', 'mpaa_rating': 'PG-13', 'total_gross': 182207973, 'inflation_adjusted_gross': 192122330}, {'title': 'Ant-Man', 'budget': 130000000.0, 'release_date': '2015-07-14', 'popularity': 26.882388, 'rating': 3.7941176470588234, 'genre': 'Action', 'mpaa_rating': 'PG-13', 'total_gross': 180202163, 'inflation_adjusted_gross': 180202163})]
# (Background on this error at: http://sqlalche.me/e/gkpj)
